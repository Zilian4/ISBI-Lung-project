# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,roc_auc_score,classification_report,recall_score,precision_score
import xgboost as xgb
import numpy as np

# %%
import json
with open(r'F:\Myproject\ISBI-Lung-project\five_fold_cv.json', 'r') as file:
    file = json.load(file)

# %%
def get_results(acc_list,auc_list,recall_list,precision_list):    
    acc_list = np.array(acc_list)
    auc_list = np.array(auc_list)
    recall_list = np.array(recall_list)
    precision_list = np.array(precision_list)
    print(f'Recall, Average:{recall_list.mean():.4f}, Std:{recall_list.std():.4f}')
    print(f'precision, Average:{precision_list.mean():.4f}, Std:{precision_list.std():.4f}')
    print(f'Accuracy, Average:{acc_list.mean():.4f}, Std:{acc_list.std():.4f}')
    print(f'AUC, Average:{auc_list.mean():.4f}, Std:{auc_list.std():.4f}')

# %%
val_acc_list = []
val_auc_list = []
val_recall_list = []
val_precision_list = []

test_acc_list = []
test_auc_list = []
test_recall_list = []
test_precision_list = []
for fold in range(5):
    print(f"Taining Fold{fold+1} .....")
    test_file = file['test_split']
    train_file = file['cross_validation'][fold]['train_files']
    val_file = file['cross_validation'][fold]['validation_files']
    
    data = pd.read_csv(r'F:\Myproject\ISBI-Lung-project\Lung_data.csv')
    tarin_data = data[data['Image'].isin(train_file)]
    val_data = data[data['Image'].isin(val_file)]
    test_data = data[data['Image'].isin(test_file)]

    train_x = tarin_data.iloc[:,:-2]
    train_y = tarin_data[["label"]]

    val_x = val_data.iloc[:,:-2]
    val_y = val_data[["label"]]

    test_x = test_data.iloc[:,:-2]
    test_y = test_data[["label"]]
    
    standard_scaler = StandardScaler()
    train_x = standard_scaler.fit_transform(train_x)
    val_x = standard_scaler.transform(val_x)
    test_x = standard_scaler.transform(test_x)

    model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='auc', n_estimators=200,max_depth = 30,learning_rate=0.3)
    # Train the model with validation data
    model.fit(train_x, train_y, eval_set=[(val_x, val_y)], verbose=True)

    # Get predicted probabilities
    # -------------------validation----------------
    y_pred_proba = model.predict(val_x)  # Get probabilities for the positive class
    y_pred = model.predict(val_x)

    accuracy = accuracy_score(val_y, y_pred)
    # print(f'Accuracy: {accuracy:.4f}')
    val_acc_list.append(accuracy)
    
    auc_score = roc_auc_score(val_y, y_pred_proba)
    # print(f'AUC Score: {auc_score:.4f}')
    val_auc_list.append(auc_score)
    
    # Print the classification report
    recall = recall_score(val_y, y_pred)
    # print(f'Recall Score: {recall:.4f}')
    val_recall_list.append(recall)
    
    precision = precision_score(val_y, y_pred)
    # print(f'AUC Score: {precision:.4f}')
    val_precision_list.append(precision)
    
    
    # Get predicted probabilities
    # -------------------testing--------------
    y_pred_proba = model.predict(test_x)  # Get probabilities for the positive class
    y_pred = model.predict(test_x)

    accuracy = accuracy_score(test_y, y_pred)
    # print(f'Accuracy: {accuracy:.4f}')
    test_acc_list.append(accuracy)
    
    auc_score = roc_auc_score(test_y, y_pred_proba)
    # print(f'AUC Score: {auc_score:.4f}')
    test_auc_list.append(auc_score)
    
    # Print the classification report
    recall = recall_score(test_y, y_pred)
    # print(f'Recall Score: {recall:.4f}')
    test_recall_list.append(recall)
    
    precision = precision_score(test_y, y_pred)
    # print(f'AUC Score: {precision:.4f}')
    test_precision_list.append(precision)
    
print('Validation set')
get_results(val_acc_list,val_auc_list,val_recall_list,val_precision_list)
print('--------------------')
print("Test set")
get_results(test_acc_list,test_auc_list,test_recall_list,test_precision_list)
print('================================================')
# Out:
# Taining Fold1 .....
# [13:24:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { use_label_encoder } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.71708
# [1]	validation_0-auc:0.74023
# [2]	validation_0-auc:0.77315
# [3]	validation_0-auc:0.78807
# [4]	validation_0-auc:0.80658
# [5]	validation_0-auc:0.78549
# [6]	validation_0-auc:0.79270
# [7]	validation_0-auc:0.77160
# [8]	validation_0-auc:0.78292
# [9]	validation_0-auc:0.79527
# [10]	validation_0-auc:0.79424
# [11]	validation_0-auc:0.79012
# [12]	validation_0-auc:0.79527
# [13]	validation_0-auc:0.79527
# [14]	validation_0-auc:0.80658
# [15]	validation_0-auc:0.81070
# [16]	validation_0-auc:0.81070
# [17]	validation_0-auc:0.81790
# [18]	validation_0-auc:0.81173
# [19]	validation_0-auc:0.79527
# [20]	validation_0-auc:0.79835
# [21]	validation_0-auc:0.79321
# [22]	validation_0-auc:0.79321
# [23]	validation_0-auc:0.79321
# [24]	validation_0-auc:0.79424
# [25]	validation_0-auc:0.79115
# [26]	validation_0-auc:0.79938
# [27]	validation_0-auc:0.78704
# [28]	validation_0-auc:0.78704
# [29]	validation_0-auc:0.78395
# [30]	validation_0-auc:0.77983
# [31]	validation_0-auc:0.77983
# [32]	validation_0-auc:0.77983
# [33]	validation_0-auc:0.77881
# [34]	validation_0-auc:0.78189
# [35]	validation_0-auc:0.77675
# [36]	validation_0-auc:0.77572
# [37]	validation_0-auc:0.77881
# [38]	validation_0-auc:0.77675
# [39]	validation_0-auc:0.77675
# [40]	validation_0-auc:0.77778
# [41]	validation_0-auc:0.78189
# [42]	validation_0-auc:0.77983
# [43]	validation_0-auc:0.78395
# [44]	validation_0-auc:0.78395
# [45]	validation_0-auc:0.78498
# f:\Anaconda3\envs\radiomics\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [46]	validation_0-auc:0.78189
# [47]	validation_0-auc:0.77778
# [48]	validation_0-auc:0.77881
# [49]	validation_0-auc:0.78086
# [50]	validation_0-auc:0.77983
# [51]	validation_0-auc:0.78189
# [52]	validation_0-auc:0.78704
# [53]	validation_0-auc:0.78601
# [54]	validation_0-auc:0.78704
# [55]	validation_0-auc:0.78704
# [56]	validation_0-auc:0.79115
# [57]	validation_0-auc:0.78498
# [58]	validation_0-auc:0.78395
# [59]	validation_0-auc:0.78292
# [60]	validation_0-auc:0.77983
# [61]	validation_0-auc:0.77983
# [62]	validation_0-auc:0.78189
# [63]	validation_0-auc:0.78086
# [64]	validation_0-auc:0.78292
# [65]	validation_0-auc:0.78292
# [66]	validation_0-auc:0.78292
# [67]	validation_0-auc:0.78498
# [68]	validation_0-auc:0.78395
# [69]	validation_0-auc:0.78601
# [70]	validation_0-auc:0.78498
# [71]	validation_0-auc:0.78395
# [72]	validation_0-auc:0.78395
# [73]	validation_0-auc:0.78498
# [74]	validation_0-auc:0.78292
# [75]	validation_0-auc:0.78395
# [76]	validation_0-auc:0.78292
# [77]	validation_0-auc:0.78601
# [78]	validation_0-auc:0.78189
# [79]	validation_0-auc:0.77983
# [80]	validation_0-auc:0.78189
# [81]	validation_0-auc:0.77881
# [82]	validation_0-auc:0.77983
# [83]	validation_0-auc:0.78189
# [84]	validation_0-auc:0.78189
# [85]	validation_0-auc:0.78395
# [86]	validation_0-auc:0.78395
# [87]	validation_0-auc:0.78498
# [88]	validation_0-auc:0.78601
# [89]	validation_0-auc:0.78601
# [90]	validation_0-auc:0.78395
# [91]	validation_0-auc:0.78292
# [92]	validation_0-auc:0.78189
# [93]	validation_0-auc:0.78189
# [94]	validation_0-auc:0.78189
# [95]	validation_0-auc:0.78498
# [96]	validation_0-auc:0.78395
# [97]	validation_0-auc:0.78498
# [98]	validation_0-auc:0.78395
# [99]	validation_0-auc:0.78395
# [100]	validation_0-auc:0.78395
# [101]	validation_0-auc:0.78189
# [102]	validation_0-auc:0.78086
# [103]	validation_0-auc:0.78292
# [104]	validation_0-auc:0.78189
# [105]	validation_0-auc:0.77983
# [106]	validation_0-auc:0.77983
# [107]	validation_0-auc:0.78086
# [108]	validation_0-auc:0.78189
# [109]	validation_0-auc:0.78086
# [110]	validation_0-auc:0.78292
# [111]	validation_0-auc:0.78189
# [112]	validation_0-auc:0.78189
# [113]	validation_0-auc:0.78292
# [114]	validation_0-auc:0.78086
# [115]	validation_0-auc:0.78086
# [116]	validation_0-auc:0.78292
# [117]	validation_0-auc:0.78292
# [118]	validation_0-auc:0.78086
# [119]	validation_0-auc:0.78086
# [120]	validation_0-auc:0.77983
# [121]	validation_0-auc:0.78086
# [122]	validation_0-auc:0.78292
# [123]	validation_0-auc:0.78189
# [124]	validation_0-auc:0.77983
# [125]	validation_0-auc:0.78189
# [126]	validation_0-auc:0.78189
# [127]	validation_0-auc:0.78086
# [128]	validation_0-auc:0.77983
# [129]	validation_0-auc:0.77983
# [130]	validation_0-auc:0.77778
# [131]	validation_0-auc:0.77778
# [132]	validation_0-auc:0.77675
# [133]	validation_0-auc:0.77983
# [134]	validation_0-auc:0.77983
# [135]	validation_0-auc:0.77778
# [136]	validation_0-auc:0.77778
# [137]	validation_0-auc:0.77778
# [138]	validation_0-auc:0.77778
# [139]	validation_0-auc:0.77675
# [140]	validation_0-auc:0.77881
# [141]	validation_0-auc:0.77983
# [142]	validation_0-auc:0.77778
# [143]	validation_0-auc:0.77675
# [144]	validation_0-auc:0.77881
# [145]	validation_0-auc:0.77881
# [146]	validation_0-auc:0.77881
# [147]	validation_0-auc:0.77675
# [148]	validation_0-auc:0.77675
# [149]	validation_0-auc:0.77675
# [150]	validation_0-auc:0.77572
# [151]	validation_0-auc:0.77675
# [152]	validation_0-auc:0.77675
# [153]	validation_0-auc:0.77881
# [154]	validation_0-auc:0.77881
# [155]	validation_0-auc:0.77983
# [156]	validation_0-auc:0.77983
# [157]	validation_0-auc:0.77778
# [158]	validation_0-auc:0.77778
# [159]	validation_0-auc:0.77778
# [160]	validation_0-auc:0.77778
# [161]	validation_0-auc:0.77675
# [162]	validation_0-auc:0.77675
# [163]	validation_0-auc:0.77778
# [164]	validation_0-auc:0.78086
# [165]	validation_0-auc:0.78086
# [166]	validation_0-auc:0.77778
# [167]	validation_0-auc:0.77881
# [168]	validation_0-auc:0.77778
# [169]	validation_0-auc:0.77983
# [170]	validation_0-auc:0.77778
# [171]	validation_0-auc:0.77881
# [172]	validation_0-auc:0.77983
# [173]	validation_0-auc:0.77881
# [174]	validation_0-auc:0.77983
# [175]	validation_0-auc:0.77983
# [176]	validation_0-auc:0.77881
# [177]	validation_0-auc:0.77983
# [178]	validation_0-auc:0.77675
# [179]	validation_0-auc:0.78086
# [180]	validation_0-auc:0.78086
# [181]	validation_0-auc:0.77983
# [182]	validation_0-auc:0.78086
# [183]	validation_0-auc:0.78189
# [184]	validation_0-auc:0.78395
# [185]	validation_0-auc:0.78395
# [186]	validation_0-auc:0.78395
# [187]	validation_0-auc:0.78498
# [188]	validation_0-auc:0.78704
# [189]	validation_0-auc:0.78498
# [190]	validation_0-auc:0.78395
# [191]	validation_0-auc:0.78498
# [192]	validation_0-auc:0.78498
# [193]	validation_0-auc:0.78292
# [194]	validation_0-auc:0.78189
# [195]	validation_0-auc:0.78086
# [196]	validation_0-auc:0.78498
# [197]	validation_0-auc:0.78189
# [198]	validation_0-auc:0.78189
# [199]	validation_0-auc:0.77983
# Taining Fold2 .....
# [13:24:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { use_label_encoder } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.54232
# [1]	validation_0-auc:0.68182
# [2]	validation_0-auc:0.69749
# [3]	validation_0-auc:0.71212
# [4]	validation_0-auc:0.68652
# [5]	validation_0-auc:0.70637
# [6]	validation_0-auc:0.69383
# [7]	validation_0-auc:0.68443
# [8]	validation_0-auc:0.69383
# [9]	validation_0-auc:0.69175
# [10]	validation_0-auc:0.70010
# [11]	validation_0-auc:0.68861
# [12]	validation_0-auc:0.67607
# [13]	validation_0-auc:0.69070
# [14]	validation_0-auc:0.69279
# [15]	validation_0-auc:0.69488
# [16]	validation_0-auc:0.69070
# [17]	validation_0-auc:0.69279
# [18]	validation_0-auc:0.70533
# [19]	validation_0-auc:0.69906
# [20]	validation_0-auc:0.69802
# [21]	validation_0-auc:0.69906
# [22]	validation_0-auc:0.70010
# [23]	validation_0-auc:0.69488
# [24]	validation_0-auc:0.69488
# [25]	validation_0-auc:0.69906
# [26]	validation_0-auc:0.70324
# [27]	validation_0-auc:0.70324
# [28]	validation_0-auc:0.70324
# [29]	validation_0-auc:0.70115
# [30]	validation_0-auc:0.69906
# [31]	validation_0-auc:0.69593
# [32]	validation_0-auc:0.69697
# [33]	validation_0-auc:0.69593
# [34]	validation_0-auc:0.68861
# [35]	validation_0-auc:0.69070
# [36]	validation_0-auc:0.68756
# [37]	validation_0-auc:0.68443
# [38]	validation_0-auc:0.68234
# [39]	validation_0-auc:0.68547
# [40]	validation_0-auc:0.68547
# [41]	validation_0-auc:0.68861
# [42]	validation_0-auc:0.68443
# [43]	validation_0-auc:0.68966
# [44]	validation_0-auc:0.68861
# [45]	validation_0-auc:0.68966
# [46]	validation_0-auc:0.68652
# [47]	validation_0-auc:0.68861
# [48]	validation_0-auc:0.69279
# [49]	validation_0-auc:0.69175
# [50]	validation_0-auc:0.69383
# [51]	validation_0-auc:0.69383
# [52]	validation_0-auc:0.69279
# [53]	validation_0-auc:0.69279
# [54]	validation_0-auc:0.69488
# [55]	validation_0-auc:0.69175
# [56]	validation_0-auc:0.68861
# [57]	validation_0-auc:0.68966
# [58]	validation_0-auc:0.68966
# [59]	validation_0-auc:0.68861
# [60]	validation_0-auc:0.68966
# [61]	validation_0-auc:0.68966
# [62]	validation_0-auc:0.69070
# [63]	validation_0-auc:0.68966
# [64]	validation_0-auc:0.68966
# [65]	validation_0-auc:0.68861
# [66]	validation_0-auc:0.68861
# [67]	validation_0-auc:0.68966
# [68]	validation_0-auc:0.68861
# [69]	validation_0-auc:0.68652
# [70]	validation_0-auc:0.68652
# f:\Anaconda3\envs\radiomics\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [71]	validation_0-auc:0.68861
# [72]	validation_0-auc:0.69070
# [73]	validation_0-auc:0.69070
# [74]	validation_0-auc:0.68756
# [75]	validation_0-auc:0.68652
# [76]	validation_0-auc:0.68756
# [77]	validation_0-auc:0.68861
# [78]	validation_0-auc:0.68861
# [79]	validation_0-auc:0.68756
# [80]	validation_0-auc:0.68756
# [81]	validation_0-auc:0.68861
# [82]	validation_0-auc:0.68966
# [83]	validation_0-auc:0.68861
# [84]	validation_0-auc:0.68756
# [85]	validation_0-auc:0.68966
# [86]	validation_0-auc:0.69383
# [87]	validation_0-auc:0.69070
# [88]	validation_0-auc:0.69070
# [89]	validation_0-auc:0.69175
# [90]	validation_0-auc:0.69070
# [91]	validation_0-auc:0.69279
# [92]	validation_0-auc:0.69279
# [93]	validation_0-auc:0.69070
# [94]	validation_0-auc:0.68966
# [95]	validation_0-auc:0.68966
# [96]	validation_0-auc:0.69070
# [97]	validation_0-auc:0.69175
# [98]	validation_0-auc:0.68966
# [99]	validation_0-auc:0.68966
# [100]	validation_0-auc:0.68966
# [101]	validation_0-auc:0.69070
# [102]	validation_0-auc:0.68861
# [103]	validation_0-auc:0.68756
# [104]	validation_0-auc:0.68756
# [105]	validation_0-auc:0.69175
# [106]	validation_0-auc:0.68861
# [107]	validation_0-auc:0.68861
# [108]	validation_0-auc:0.68966
# [109]	validation_0-auc:0.68547
# [110]	validation_0-auc:0.68652
# [111]	validation_0-auc:0.68652
# [112]	validation_0-auc:0.68861
# [113]	validation_0-auc:0.68756
# [114]	validation_0-auc:0.68861
# [115]	validation_0-auc:0.68652
# [116]	validation_0-auc:0.68756
# [117]	validation_0-auc:0.68966
# [118]	validation_0-auc:0.68966
# [119]	validation_0-auc:0.68756
# [120]	validation_0-auc:0.68861
# [121]	validation_0-auc:0.68652
# [122]	validation_0-auc:0.68443
# [123]	validation_0-auc:0.68652
# [124]	validation_0-auc:0.68756
# [125]	validation_0-auc:0.68756
# [126]	validation_0-auc:0.69383
# [127]	validation_0-auc:0.69383
# [128]	validation_0-auc:0.69175
# [129]	validation_0-auc:0.68966
# [130]	validation_0-auc:0.69175
# [131]	validation_0-auc:0.69175
# [132]	validation_0-auc:0.68966
# [133]	validation_0-auc:0.69383
# [134]	validation_0-auc:0.69593
# [135]	validation_0-auc:0.69070
# [136]	validation_0-auc:0.69279
# [137]	validation_0-auc:0.68966
# [138]	validation_0-auc:0.68861
# [139]	validation_0-auc:0.69070
# [140]	validation_0-auc:0.69175
# [141]	validation_0-auc:0.68861
# [142]	validation_0-auc:0.68861
# [143]	validation_0-auc:0.68966
# [144]	validation_0-auc:0.69175
# [145]	validation_0-auc:0.69070
# [146]	validation_0-auc:0.68861
# [147]	validation_0-auc:0.68966
# [148]	validation_0-auc:0.68861
# [149]	validation_0-auc:0.69070
# [150]	validation_0-auc:0.69070
# [151]	validation_0-auc:0.69070
# [152]	validation_0-auc:0.69070
# [153]	validation_0-auc:0.69070
# [154]	validation_0-auc:0.69070
# [155]	validation_0-auc:0.69070
# [156]	validation_0-auc:0.69279
# [157]	validation_0-auc:0.68966
# [158]	validation_0-auc:0.68861
# [159]	validation_0-auc:0.68966
# [160]	validation_0-auc:0.68966
# [161]	validation_0-auc:0.69070
# [162]	validation_0-auc:0.69175
# [163]	validation_0-auc:0.68861
# [164]	validation_0-auc:0.68756
# [165]	validation_0-auc:0.68861
# [166]	validation_0-auc:0.68861
# [167]	validation_0-auc:0.68966
# [168]	validation_0-auc:0.69070
# [169]	validation_0-auc:0.68966
# [170]	validation_0-auc:0.68966
# [171]	validation_0-auc:0.69175
# [172]	validation_0-auc:0.69279
# [173]	validation_0-auc:0.69175
# [174]	validation_0-auc:0.69070
# [175]	validation_0-auc:0.69070
# [176]	validation_0-auc:0.69070
# [177]	validation_0-auc:0.68861
# [178]	validation_0-auc:0.68756
# [179]	validation_0-auc:0.69070
# [180]	validation_0-auc:0.68756
# [181]	validation_0-auc:0.68652
# [182]	validation_0-auc:0.68652
# [183]	validation_0-auc:0.68756
# [184]	validation_0-auc:0.69279
# [185]	validation_0-auc:0.68966
# [186]	validation_0-auc:0.69070
# [187]	validation_0-auc:0.69070
# [188]	validation_0-auc:0.68756
# [189]	validation_0-auc:0.69175
# [190]	validation_0-auc:0.69175
# [191]	validation_0-auc:0.68861
# [192]	validation_0-auc:0.68861
# [193]	validation_0-auc:0.68756
# [194]	validation_0-auc:0.68966
# [195]	validation_0-auc:0.69279
# [196]	validation_0-auc:0.69175
# [197]	validation_0-auc:0.69175
# [198]	validation_0-auc:0.69279
# [199]	validation_0-auc:0.69279
# Taining Fold3 .....
# [13:24:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { use_label_encoder } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.59643
# [1]	validation_0-auc:0.59235
# [2]	validation_0-auc:0.59541
# [3]	validation_0-auc:0.60459
# [4]	validation_0-auc:0.61888
# [5]	validation_0-auc:0.62551
# [6]	validation_0-auc:0.62602
# [7]	validation_0-auc:0.62500
# [8]	validation_0-auc:0.62806
# [9]	validation_0-auc:0.63316
# [10]	validation_0-auc:0.64541
# [11]	validation_0-auc:0.64541
# [12]	validation_0-auc:0.64541
# [13]	validation_0-auc:0.65051
# [14]	validation_0-auc:0.65051
# [15]	validation_0-auc:0.65459
# [16]	validation_0-auc:0.64949
# [17]	validation_0-auc:0.65357
# [18]	validation_0-auc:0.65255
# [19]	validation_0-auc:0.65765
# [20]	validation_0-auc:0.65459
# [21]	validation_0-auc:0.66275
# [22]	validation_0-auc:0.66275
# [23]	validation_0-auc:0.65561
# [24]	validation_0-auc:0.65357
# [25]	validation_0-auc:0.65561
# [26]	validation_0-auc:0.65153
# [27]	validation_0-auc:0.65459
# [28]	validation_0-auc:0.65867
# [29]	validation_0-auc:0.65969
# [30]	validation_0-auc:0.65765
# [31]	validation_0-auc:0.65867
# [32]	validation_0-auc:0.66275
# [33]	validation_0-auc:0.66173
# [34]	validation_0-auc:0.66173
# [35]	validation_0-auc:0.66173
# [36]	validation_0-auc:0.66275
# [37]	validation_0-auc:0.66071
# [38]	validation_0-auc:0.66275
# [39]	validation_0-auc:0.66173
# [40]	validation_0-auc:0.66173
# [41]	validation_0-auc:0.66480
# [42]	validation_0-auc:0.66378
# [43]	validation_0-auc:0.66582
# [44]	validation_0-auc:0.66275
# [45]	validation_0-auc:0.65867
# [46]	validation_0-auc:0.66480
# [47]	validation_0-auc:0.66275
# [48]	validation_0-auc:0.65969
# [49]	validation_0-auc:0.65867
# [50]	validation_0-auc:0.66173
# [51]	validation_0-auc:0.66071
# [52]	validation_0-auc:0.65663
# [53]	validation_0-auc:0.65459
# [54]	validation_0-auc:0.65765
# [55]	validation_0-auc:0.65867
# [56]	validation_0-auc:0.65765
# [57]	validation_0-auc:0.65663
# [58]	validation_0-auc:0.65765
# [59]	validation_0-auc:0.65663
# [60]	validation_0-auc:0.65357
# [61]	validation_0-auc:0.64949
# [62]	validation_0-auc:0.64949
# [63]	validation_0-auc:0.65153
# f:\Anaconda3\envs\radiomics\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [64]	validation_0-auc:0.65255
# [65]	validation_0-auc:0.65153
# [66]	validation_0-auc:0.65255
# [67]	validation_0-auc:0.65255
# [68]	validation_0-auc:0.65561
# [69]	validation_0-auc:0.65663
# [70]	validation_0-auc:0.65459
# [71]	validation_0-auc:0.65561
# [72]	validation_0-auc:0.65561
# [73]	validation_0-auc:0.65561
# [74]	validation_0-auc:0.65459
# [75]	validation_0-auc:0.65459
# [76]	validation_0-auc:0.65561
# [77]	validation_0-auc:0.65765
# [78]	validation_0-auc:0.65561
# [79]	validation_0-auc:0.65459
# [80]	validation_0-auc:0.65765
# [81]	validation_0-auc:0.65867
# [82]	validation_0-auc:0.66173
# [83]	validation_0-auc:0.66480
# [84]	validation_0-auc:0.66684
# [85]	validation_0-auc:0.66582
# [86]	validation_0-auc:0.66582
# [87]	validation_0-auc:0.66378
# [88]	validation_0-auc:0.66275
# [89]	validation_0-auc:0.66071
# [90]	validation_0-auc:0.65969
# [91]	validation_0-auc:0.66173
# [92]	validation_0-auc:0.66071
# [93]	validation_0-auc:0.66378
# [94]	validation_0-auc:0.66275
# [95]	validation_0-auc:0.66173
# [96]	validation_0-auc:0.65969
# [97]	validation_0-auc:0.65867
# [98]	validation_0-auc:0.66071
# [99]	validation_0-auc:0.65867
# [100]	validation_0-auc:0.65969
# [101]	validation_0-auc:0.65969
# [102]	validation_0-auc:0.65765
# [103]	validation_0-auc:0.65765
# [104]	validation_0-auc:0.65765
# [105]	validation_0-auc:0.65867
# [106]	validation_0-auc:0.66173
# [107]	validation_0-auc:0.65969
# [108]	validation_0-auc:0.65969
# [109]	validation_0-auc:0.65969
# [110]	validation_0-auc:0.65969
# [111]	validation_0-auc:0.65969
# [112]	validation_0-auc:0.65867
# [113]	validation_0-auc:0.65765
# [114]	validation_0-auc:0.66071
# [115]	validation_0-auc:0.66275
# [116]	validation_0-auc:0.66071
# [117]	validation_0-auc:0.65867
# [118]	validation_0-auc:0.65765
# [119]	validation_0-auc:0.65867
# [120]	validation_0-auc:0.65969
# [121]	validation_0-auc:0.65867
# [122]	validation_0-auc:0.65969
# [123]	validation_0-auc:0.65765
# [124]	validation_0-auc:0.65459
# [125]	validation_0-auc:0.65561
# [126]	validation_0-auc:0.65663
# [127]	validation_0-auc:0.65765
# [128]	validation_0-auc:0.65867
# [129]	validation_0-auc:0.65969
# [130]	validation_0-auc:0.65969
# [131]	validation_0-auc:0.65765
# [132]	validation_0-auc:0.65663
# [133]	validation_0-auc:0.65969
# [134]	validation_0-auc:0.65867
# [135]	validation_0-auc:0.65459
# [136]	validation_0-auc:0.65561
# [137]	validation_0-auc:0.65765
# [138]	validation_0-auc:0.65663
# [139]	validation_0-auc:0.65663
# [140]	validation_0-auc:0.65969
# [141]	validation_0-auc:0.65867
# [142]	validation_0-auc:0.65969
# [143]	validation_0-auc:0.65765
# [144]	validation_0-auc:0.65561
# [145]	validation_0-auc:0.65765
# [146]	validation_0-auc:0.66173
# [147]	validation_0-auc:0.65969
# [148]	validation_0-auc:0.65867
# [149]	validation_0-auc:0.66275
# [150]	validation_0-auc:0.65969
# [151]	validation_0-auc:0.65867
# [152]	validation_0-auc:0.66275
# [153]	validation_0-auc:0.66275
# [154]	validation_0-auc:0.66071
# [155]	validation_0-auc:0.65969
# [156]	validation_0-auc:0.65969
# [157]	validation_0-auc:0.65969
# [158]	validation_0-auc:0.66071
# [159]	validation_0-auc:0.65969
# [160]	validation_0-auc:0.65969
# [161]	validation_0-auc:0.65867
# [162]	validation_0-auc:0.65663
# [163]	validation_0-auc:0.65969
# [164]	validation_0-auc:0.66071
# [165]	validation_0-auc:0.66071
# [166]	validation_0-auc:0.65969
# [167]	validation_0-auc:0.65663
# [168]	validation_0-auc:0.65765
# [169]	validation_0-auc:0.65663
# [170]	validation_0-auc:0.65765
# [171]	validation_0-auc:0.65969
# [172]	validation_0-auc:0.66071
# [173]	validation_0-auc:0.65969
# [174]	validation_0-auc:0.66071
# [175]	validation_0-auc:0.66071
# [176]	validation_0-auc:0.65969
# [177]	validation_0-auc:0.65867
# [178]	validation_0-auc:0.65867
# [179]	validation_0-auc:0.65765
# [180]	validation_0-auc:0.65561
# [181]	validation_0-auc:0.65765
# [182]	validation_0-auc:0.65663
# [183]	validation_0-auc:0.65561
# [184]	validation_0-auc:0.65765
# [185]	validation_0-auc:0.65765
# [186]	validation_0-auc:0.65663
# [187]	validation_0-auc:0.65765
# [188]	validation_0-auc:0.65867
# [189]	validation_0-auc:0.65867
# [190]	validation_0-auc:0.65867
# [191]	validation_0-auc:0.65867
# [192]	validation_0-auc:0.65867
# [193]	validation_0-auc:0.65969
# [194]	validation_0-auc:0.65969
# [195]	validation_0-auc:0.65969
# [196]	validation_0-auc:0.65969
# [197]	validation_0-auc:0.65765
# [198]	validation_0-auc:0.65663
# [199]	validation_0-auc:0.65765
# Taining Fold4 .....
# [13:24:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { use_label_encoder } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.71142
# [1]	validation_0-auc:0.65381
# [2]	validation_0-auc:0.65535
# [3]	validation_0-auc:0.62911
# [4]	validation_0-auc:0.64815
# [5]	validation_0-auc:0.65741
# [6]	validation_0-auc:0.65329
# [7]	validation_0-auc:0.67387
# [8]	validation_0-auc:0.66975
# [9]	validation_0-auc:0.66667
# [10]	validation_0-auc:0.67490
# [11]	validation_0-auc:0.67593
# [12]	validation_0-auc:0.66975
# [13]	validation_0-auc:0.66975
# [14]	validation_0-auc:0.66975
# [15]	validation_0-auc:0.67798
# [16]	validation_0-auc:0.68313
# [17]	validation_0-auc:0.68519
# [18]	validation_0-auc:0.67798
# [19]	validation_0-auc:0.67490
# [20]	validation_0-auc:0.67078
# [21]	validation_0-auc:0.67798
# [22]	validation_0-auc:0.67181
# [23]	validation_0-auc:0.67387
# [24]	validation_0-auc:0.67078
# [25]	validation_0-auc:0.67181
# [26]	validation_0-auc:0.67181
# [27]	validation_0-auc:0.67695
# [28]	validation_0-auc:0.67901
# [29]	validation_0-auc:0.67490
# [30]	validation_0-auc:0.67490
# [31]	validation_0-auc:0.67078
# [32]	validation_0-auc:0.67078
# [33]	validation_0-auc:0.67387
# [34]	validation_0-auc:0.67387
# [35]	validation_0-auc:0.67490
# [36]	validation_0-auc:0.67593
# [37]	validation_0-auc:0.67387
# [38]	validation_0-auc:0.67284
# [39]	validation_0-auc:0.67181
# [40]	validation_0-auc:0.66975
# [41]	validation_0-auc:0.67078
# [42]	validation_0-auc:0.67284
# [43]	validation_0-auc:0.66975
# [44]	validation_0-auc:0.67490
# [45]	validation_0-auc:0.67387
# [46]	validation_0-auc:0.67901
# [47]	validation_0-auc:0.67490
# [48]	validation_0-auc:0.67695
# [49]	validation_0-auc:0.67695
# [50]	validation_0-auc:0.67593
# [51]	validation_0-auc:0.67593
# [52]	validation_0-auc:0.67593
# [53]	validation_0-auc:0.67593
# [54]	validation_0-auc:0.67593
# [55]	validation_0-auc:0.67798
# [56]	validation_0-auc:0.67078
# [57]	validation_0-auc:0.67387
# [58]	validation_0-auc:0.67695
# [59]	validation_0-auc:0.66872
# [60]	validation_0-auc:0.67078
# [61]	validation_0-auc:0.67078
# [62]	validation_0-auc:0.67387
# [63]	validation_0-auc:0.67387
# [64]	validation_0-auc:0.67490
# [65]	validation_0-auc:0.67181
# [66]	validation_0-auc:0.67387
# [67]	validation_0-auc:0.67181
# f:\Anaconda3\envs\radiomics\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [68]	validation_0-auc:0.67284
# [69]	validation_0-auc:0.67387
# [70]	validation_0-auc:0.67284
# [71]	validation_0-auc:0.67181
# [72]	validation_0-auc:0.67284
# [73]	validation_0-auc:0.67387
# [74]	validation_0-auc:0.67181
# [75]	validation_0-auc:0.67078
# [76]	validation_0-auc:0.66975
# [77]	validation_0-auc:0.67078
# [78]	validation_0-auc:0.67181
# [79]	validation_0-auc:0.67387
# [80]	validation_0-auc:0.67593
# [81]	validation_0-auc:0.67284
# [82]	validation_0-auc:0.67284
# [83]	validation_0-auc:0.67284
# [84]	validation_0-auc:0.67284
# [85]	validation_0-auc:0.67181
# [86]	validation_0-auc:0.67284
# [87]	validation_0-auc:0.67181
# [88]	validation_0-auc:0.67284
# [89]	validation_0-auc:0.67284
# [90]	validation_0-auc:0.67181
# [91]	validation_0-auc:0.67490
# [92]	validation_0-auc:0.67181
# [93]	validation_0-auc:0.67284
# [94]	validation_0-auc:0.67078
# [95]	validation_0-auc:0.66872
# [96]	validation_0-auc:0.66770
# [97]	validation_0-auc:0.66872
# [98]	validation_0-auc:0.67078
# [99]	validation_0-auc:0.67181
# [100]	validation_0-auc:0.67387
# [101]	validation_0-auc:0.67078
# [102]	validation_0-auc:0.67284
# [103]	validation_0-auc:0.67078
# [104]	validation_0-auc:0.67181
# [105]	validation_0-auc:0.66975
# [106]	validation_0-auc:0.67181
# [107]	validation_0-auc:0.66975
# [108]	validation_0-auc:0.66975
# [109]	validation_0-auc:0.67284
# [110]	validation_0-auc:0.66975
# [111]	validation_0-auc:0.66872
# [112]	validation_0-auc:0.67078
# [113]	validation_0-auc:0.67078
# [114]	validation_0-auc:0.66975
# [115]	validation_0-auc:0.66975
# [116]	validation_0-auc:0.66667
# [117]	validation_0-auc:0.66564
# [118]	validation_0-auc:0.66872
# [119]	validation_0-auc:0.66975
# [120]	validation_0-auc:0.66975
# [121]	validation_0-auc:0.66667
# [122]	validation_0-auc:0.66564
# [123]	validation_0-auc:0.66358
# [124]	validation_0-auc:0.66358
# [125]	validation_0-auc:0.66564
# [126]	validation_0-auc:0.66770
# [127]	validation_0-auc:0.66872
# [128]	validation_0-auc:0.66872
# [129]	validation_0-auc:0.66667
# [130]	validation_0-auc:0.66667
# [131]	validation_0-auc:0.66770
# [132]	validation_0-auc:0.66872
# [133]	validation_0-auc:0.66872
# [134]	validation_0-auc:0.66872
# [135]	validation_0-auc:0.66770
# [136]	validation_0-auc:0.66667
# [137]	validation_0-auc:0.66564
# [138]	validation_0-auc:0.66770
# [139]	validation_0-auc:0.66975
# [140]	validation_0-auc:0.67078
# [141]	validation_0-auc:0.66975
# [142]	validation_0-auc:0.66770
# [143]	validation_0-auc:0.66770
# [144]	validation_0-auc:0.66872
# [145]	validation_0-auc:0.66667
# [146]	validation_0-auc:0.66770
# [147]	validation_0-auc:0.66872
# [148]	validation_0-auc:0.66770
# [149]	validation_0-auc:0.66770
# [150]	validation_0-auc:0.66770
# [151]	validation_0-auc:0.66667
# [152]	validation_0-auc:0.66667
# [153]	validation_0-auc:0.66564
# [154]	validation_0-auc:0.66461
# [155]	validation_0-auc:0.66461
# [156]	validation_0-auc:0.66461
# [157]	validation_0-auc:0.66461
# [158]	validation_0-auc:0.66255
# [159]	validation_0-auc:0.66255
# [160]	validation_0-auc:0.66255
# [161]	validation_0-auc:0.66255
# [162]	validation_0-auc:0.66461
# [163]	validation_0-auc:0.66667
# [164]	validation_0-auc:0.66564
# [165]	validation_0-auc:0.66358
# [166]	validation_0-auc:0.66358
# [167]	validation_0-auc:0.66461
# [168]	validation_0-auc:0.66461
# [169]	validation_0-auc:0.66461
# [170]	validation_0-auc:0.66358
# [171]	validation_0-auc:0.66564
# [172]	validation_0-auc:0.66564
# [173]	validation_0-auc:0.66461
# [174]	validation_0-auc:0.66461
# [175]	validation_0-auc:0.66564
# [176]	validation_0-auc:0.66564
# [177]	validation_0-auc:0.66461
# [178]	validation_0-auc:0.66358
# [179]	validation_0-auc:0.66255
# [180]	validation_0-auc:0.66358
# [181]	validation_0-auc:0.66255
# [182]	validation_0-auc:0.66049
# [183]	validation_0-auc:0.66049
# [184]	validation_0-auc:0.66152
# [185]	validation_0-auc:0.66255
# [186]	validation_0-auc:0.66152
# [187]	validation_0-auc:0.66152
# [188]	validation_0-auc:0.66152
# [189]	validation_0-auc:0.66049
# [190]	validation_0-auc:0.66049
# [191]	validation_0-auc:0.66152
# [192]	validation_0-auc:0.66152
# [193]	validation_0-auc:0.66049
# [194]	validation_0-auc:0.66049
# [195]	validation_0-auc:0.66152
# [196]	validation_0-auc:0.66152
# [197]	validation_0-auc:0.66255
# [198]	validation_0-auc:0.66255
# [199]	validation_0-auc:0.66255
# Taining Fold5 .....
# [13:24:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { use_label_encoder } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-auc:0.57760
# [1]	validation_0-auc:0.55885
# [2]	validation_0-auc:0.56719
# [3]	validation_0-auc:0.58333
# [4]	validation_0-auc:0.59896
# [5]	validation_0-auc:0.60365
# [6]	validation_0-auc:0.60521
# [7]	validation_0-auc:0.60625
# [8]	validation_0-auc:0.60938
# [9]	validation_0-auc:0.61042
# [10]	validation_0-auc:0.61562
# [11]	validation_0-auc:0.62813
# [12]	validation_0-auc:0.63125
# [13]	validation_0-auc:0.63333
# [14]	validation_0-auc:0.63958
# [15]	validation_0-auc:0.62708
# [16]	validation_0-auc:0.62708
# [17]	validation_0-auc:0.62500
# [18]	validation_0-auc:0.62500
# [19]	validation_0-auc:0.62604
# [20]	validation_0-auc:0.63750
# [21]	validation_0-auc:0.63333
# [22]	validation_0-auc:0.62396
# [23]	validation_0-auc:0.63438
# [24]	validation_0-auc:0.63021
# [25]	validation_0-auc:0.62917
# [26]	validation_0-auc:0.62604
# [27]	validation_0-auc:0.62500
# [28]	validation_0-auc:0.63438
# [29]	validation_0-auc:0.64062
# [30]	validation_0-auc:0.63333
# [31]	validation_0-auc:0.63750
# [32]	validation_0-auc:0.63750
# [33]	validation_0-auc:0.63542
# [34]	validation_0-auc:0.64167
# [35]	validation_0-auc:0.64062
# [36]	validation_0-auc:0.63750
# f:\Anaconda3\envs\radiomics\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [37]	validation_0-auc:0.63333
# [38]	validation_0-auc:0.63750
# [39]	validation_0-auc:0.63750
# [40]	validation_0-auc:0.63438
# [41]	validation_0-auc:0.63125
# [42]	validation_0-auc:0.63333
# [43]	validation_0-auc:0.63438
# [44]	validation_0-auc:0.62917
# [45]	validation_0-auc:0.63021
# [46]	validation_0-auc:0.63021
# [47]	validation_0-auc:0.63229
# [48]	validation_0-auc:0.63646
# [49]	validation_0-auc:0.63646
# [50]	validation_0-auc:0.64062
# [51]	validation_0-auc:0.63854
# [52]	validation_0-auc:0.63854
# [53]	validation_0-auc:0.64062
# [54]	validation_0-auc:0.63646
# [55]	validation_0-auc:0.63333
# [56]	validation_0-auc:0.63229
# [57]	validation_0-auc:0.63646
# [58]	validation_0-auc:0.63438
# [59]	validation_0-auc:0.63854
# [60]	validation_0-auc:0.63333
# [61]	validation_0-auc:0.63854
# [62]	validation_0-auc:0.63854
# [63]	validation_0-auc:0.63854
# [64]	validation_0-auc:0.63958
# [65]	validation_0-auc:0.63958
# [66]	validation_0-auc:0.63542
# [67]	validation_0-auc:0.63646
# [68]	validation_0-auc:0.64062
# [69]	validation_0-auc:0.63854
# [70]	validation_0-auc:0.64062
# [71]	validation_0-auc:0.63958
# [72]	validation_0-auc:0.63333
# [73]	validation_0-auc:0.63854
# [74]	validation_0-auc:0.64062
# [75]	validation_0-auc:0.64062
# [76]	validation_0-auc:0.64271
# [77]	validation_0-auc:0.63646
# [78]	validation_0-auc:0.63854
# [79]	validation_0-auc:0.64062
# [80]	validation_0-auc:0.63750
# [81]	validation_0-auc:0.63750
# [82]	validation_0-auc:0.64062
# [83]	validation_0-auc:0.63854
# [84]	validation_0-auc:0.63646
# [85]	validation_0-auc:0.63646
# [86]	validation_0-auc:0.63854
# [87]	validation_0-auc:0.63750
# [88]	validation_0-auc:0.63750
# [89]	validation_0-auc:0.64271
# [90]	validation_0-auc:0.63646
# [91]	validation_0-auc:0.64271
# [92]	validation_0-auc:0.64479
# [93]	validation_0-auc:0.64479
# [94]	validation_0-auc:0.64896
# [95]	validation_0-auc:0.64687
# [96]	validation_0-auc:0.64896
# [97]	validation_0-auc:0.64479
# [98]	validation_0-auc:0.64687
# [99]	validation_0-auc:0.64687
# [100]	validation_0-auc:0.64792
# [101]	validation_0-auc:0.64375
# [102]	validation_0-auc:0.64687
# [103]	validation_0-auc:0.64687
# [104]	validation_0-auc:0.64896
# [105]	validation_0-auc:0.64687
# [106]	validation_0-auc:0.64583
# [107]	validation_0-auc:0.64375
# [108]	validation_0-auc:0.64583
# [109]	validation_0-auc:0.64271
# [110]	validation_0-auc:0.64375
# [111]	validation_0-auc:0.64583
# [112]	validation_0-auc:0.64479
# [113]	validation_0-auc:0.64271
# [114]	validation_0-auc:0.64583
# [115]	validation_0-auc:0.64167
# [116]	validation_0-auc:0.64271
# [117]	validation_0-auc:0.64375
# [118]	validation_0-auc:0.64479
# [119]	validation_0-auc:0.64479
# [120]	validation_0-auc:0.64375
# [121]	validation_0-auc:0.64375
# [122]	validation_0-auc:0.64479
# [123]	validation_0-auc:0.64167
# [124]	validation_0-auc:0.64062
# [125]	validation_0-auc:0.64375
# [126]	validation_0-auc:0.64583
# [127]	validation_0-auc:0.64271
# [128]	validation_0-auc:0.64375
# [129]	validation_0-auc:0.64271
# [130]	validation_0-auc:0.64479
# [131]	validation_0-auc:0.64167
# [132]	validation_0-auc:0.64271
# [133]	validation_0-auc:0.64479
# [134]	validation_0-auc:0.64375
# [135]	validation_0-auc:0.64687
# [136]	validation_0-auc:0.64583
# [137]	validation_0-auc:0.64583
# [138]	validation_0-auc:0.64687
# [139]	validation_0-auc:0.64479
# [140]	validation_0-auc:0.64479
# [141]	validation_0-auc:0.64583
# [142]	validation_0-auc:0.64583
# [143]	validation_0-auc:0.64687
# [144]	validation_0-auc:0.64792
# [145]	validation_0-auc:0.64687
# [146]	validation_0-auc:0.64792
# [147]	validation_0-auc:0.64792
# [148]	validation_0-auc:0.65104
# [149]	validation_0-auc:0.65208
# [150]	validation_0-auc:0.65417
# [151]	validation_0-auc:0.65000
# [152]	validation_0-auc:0.65000
# [153]	validation_0-auc:0.65000
# [154]	validation_0-auc:0.65104
# [155]	validation_0-auc:0.65208
# [156]	validation_0-auc:0.65000
# [157]	validation_0-auc:0.65208
# [158]	validation_0-auc:0.65104
# [159]	validation_0-auc:0.65208
# [160]	validation_0-auc:0.65104
# [161]	validation_0-auc:0.65104
# [162]	validation_0-auc:0.65208
# [163]	validation_0-auc:0.65104
# [164]	validation_0-auc:0.65208
# [165]	validation_0-auc:0.65104
# [166]	validation_0-auc:0.65208
# [167]	validation_0-auc:0.65208
# [168]	validation_0-auc:0.65312
# [169]	validation_0-auc:0.65208
# [170]	validation_0-auc:0.65104
# [171]	validation_0-auc:0.65000
# [172]	validation_0-auc:0.64896
# [173]	validation_0-auc:0.65104
# [174]	validation_0-auc:0.65312
# [175]	validation_0-auc:0.65312
# [176]	validation_0-auc:0.65208
# [177]	validation_0-auc:0.65000
# [178]	validation_0-auc:0.65104
# [179]	validation_0-auc:0.65312
# [180]	validation_0-auc:0.65417
# [181]	validation_0-auc:0.65312
# [182]	validation_0-auc:0.65312
# [183]	validation_0-auc:0.65417
# [184]	validation_0-auc:0.65312
# [185]	validation_0-auc:0.65417
# [186]	validation_0-auc:0.65521
# [187]	validation_0-auc:0.65312
# [188]	validation_0-auc:0.65312
# [189]	validation_0-auc:0.65312
# [190]	validation_0-auc:0.65625
# [191]	validation_0-auc:0.65729
# [192]	validation_0-auc:0.65521
# [193]	validation_0-auc:0.65729
# [194]	validation_0-auc:0.65729
# [195]	validation_0-auc:0.65417
# [196]	validation_0-auc:0.65625
# [197]	validation_0-auc:0.65417
# [198]	validation_0-auc:0.65521
# [199]	validation_0-auc:0.65833
# Validation set
# Recall, Average:0.6130, Std:0.1291
# precision, Average:0.6632, Std:0.0715
# Accuracy, Average:0.6741, Std:0.0509
# AUC, Average:0.6730, Std:0.0548
# --------------------
# Test set
# Recall, Average:0.8167, Std:0.0624
# precision, Average:0.6626, Std:0.0330
# Accuracy, Average:0.7882, Std:0.0288
# AUC, Average:0.7947, Std:0.0343
# ================================================
